# %% [markdown]
# # Plants vs. Zombies 2: Level Upgrade Tables
#
# *A web scraping project using Python Selenium WebDriver and BeautifulSoup4.*
#
# ## Table of Contents
#
# - **Import Python Packages**
# - **Selenium WebDriver: Chrome Driver**
#   - Step 1: Configure Selenium WebDriver for Chrome browser.
#   - Step 2: Maximize the browser window, then open the Plants vs Zombies 2 - Plant page.
#   - Step 3: Extract the links to plant pages of all currently available plants.
# - **Beautiful Soup 4**
#   - Step 4: Extract the Level Upgrade Table from the plant page.
# - **Pandas**
#   - Step 5: Load Level Upgrade Table into pandas data frame.
#   - Step 6: Flatten column values in the Level Upgrade Table.
#   - Step 7: Remove unnecessary rows or columns due to wrong values specified in rowspan or colspan of the HTML table.
#   - Step 8: Identify columns with should be converted to numeric data types.
#   - Step 9: Convert selected columns from string to numeric data types.
#   - Step 10: Save Level Upgrade table to CSV file.
#   - Pandas: Summary
# - **Future Works**
#
# <img src='./lib/img/eugene-mykulyak-cHFXdJ9R0bo-unsplash.jpg'></img>
#
# Photo by <a href="https://unsplash.com/@eugenegrunge?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Eugene Mykulyak</a> on <a href="https://unsplash.com/s/photos/sunflower-garden?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>
#
# ---
#
# ## Import Python Packages
#
# Import necessary Python packages. Manual installation might be required for the packages below.
#
# - [`selenium`](https://pypi.org/project/selenium/): automation framework for website
# - [`webdriver_manager`](https://github.com/SergeyPirogov/webdriver_manager): installation of web drivers for different web browsers.
# - [`BeautifulSoup`](https://pypi.org/project/beautifulsoup4/) (or `bs4`): HTML and XML file parsing
# - [`pandas`](https://pypi.org/project/pandas/): data manipulation and analysis

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

from bs4 import BeautifulSoup

import pandas as pd

# %% [markdown]
# ## Selenium WebDriver: Chrome Driver
#
# ### Step 1: Configure Selenium WebDriver for Chrome browser.
#
# Configure web driver for Chrome browser by first installing `ChromeDriverManager()` from `webdriver_manager` package, then creating an instance of `Service()` which will then be passed as a parameter inside an instance of `webdriver.Chrome()` object.
#
# **Note:** Each browser has its own web driver. For instance, Firefox browser and Safari browser (MacOS) have their own web drivers, which need to be downloaded and specified prior to the web scraping process.

# %%
s = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=s)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 100.0.4896
# Get LATEST chromedriver version for 100.0.4896 google-chrome
# Driver [C:\Users\Darren Lee\.wdm\drivers\chromedriver\win32\100.0.4896.60\chromedriver.exe] found in cache

# %% [markdown]
# The goal of this simple web scraping project is to obtain information written in the **"Level Upgrade"** section on the wiki page for all 100+ currently available plants. We start by first opening the [Plants vs Zombies 2 - Plant page](https://plantsvszombies.fandom.com/wiki/Plants_(PvZ2)). This page lists all plants currently available in the Plant vs Zombie 2 gameplay according to their category (the world that these plants get unlocked).
#
# ### Step 2: Maximize the browser window, then open the Plants vs Zombies 2 - Plant page.
#
# - `driver.maximize_window()`: Maximize the browser window controlled by the web driver.
# - `driver.get(<URL>)`: Opens the specified `url` on the browser window.

# %%
driver.maximize_window()
driver.get("https://plantsvszombies.fandom.com/wiki/Plants_(PvZ2)")

# %% [markdown]
# ### Step 3: Extract the links to plant pages of all currently available plants.
#
# On the [Plants vs Zombies 2 - Plant page](https://plantsvszombies.fandom.com/wiki/Plants_(PvZ2)), the accordion below **"See More"** section contains the links to all plants available in the Plants vs. Zombies games of different versions. In particular, the plants available in Plants vs. Zombies 2 are listed below **"Plants vs. Zombies 2"** on the accordion.
#
# Therefore, we use `.find_all(<list of tags>)` method to extract the links/anchors of the corresponding plants and store them **into a list**.
#
# Full XPath:
# ```
# //font[contains(text(), 'Plants vs. Zombies 2')]/parent::strong/parent::i/parent::th/parent::tr/following-sibling::tr//td[@style='border-color:transparent' or @style='background:transparent border-color:transparent']/a"
# ```
#
# Breakdown of each component in the XPath:
#
# - `//font[contains(text(), 'Plants vs. Zombies 2')]`: The base element is a `font` element with text "Plants vs. Zombies 2".
# - `/parent::strong/parent::i/parent::th/parent::tr`: The traversal back to the parent element `tr` which consists of all links/anchors to the respective plant pages.
# - `//td[@style='border-color:transparent' or @style='background:transparent border-color:transparent']/a`: The links/anchors to the respective plant pages are child elements with shared attributes, i.e. `@style`, specified within the square brackets.

# %%
XPATH_PVZ2_PLANTS = "//font[contains(text(), 'Plants vs. Zombies 2')]/parent::strong/parent::i/parent::th/parent::tr/following-sibling::tr"
XPATH_PVZ2_PLANTS += "//td[@style='border-color:transparent' or @style='background:transparent border-color:transparent']/a"

plant_page_link_elements = driver.find_elements(By.XPATH, XPATH_PVZ2_PLANTS)

print("Success!")
# Out:
# Success!

# %% [markdown]
# Next, get the lists of plant names and links to the corresponding plant pages.

# %%
plant_page_links = list(map(lambda x: x.get_attribute('href'), plant_page_link_elements))
plant_names = list(map(lambda x: x.get_attribute('text'), plant_page_link_elements))

print("Success!")
# Out:
# Success!

# %% [markdown]
# Print the lists of plants available in Plants vs. Zombies 2 and their corresponding plant details page.
#
# **Note:** Some plants appear across different Plants vs. Zombies gameplay, whereas some are introduced exclusively for this gameplay. Therefore, it is important to obtain the correct links to the plants, which contain the correct information relevant to Plants vs. Zombies 2 only.

# %%
print("There are", len(plant_names), "plants, as follows:")
print("-"*50)
_ = [print(f"{i+1}. {n}: {url}") for i, (n, url) in enumerate(zip(plant_names, plant_page_links))]
# Out:
# There are 170 plants, as follows:
# --------------------------------------------------
# 1. Peashooter: https://plantsvszombies.fandom.com/wiki/Peashooter_(PvZ2)
# 2. Sunflower: https://plantsvszombies.fandom.com/wiki/Sunflower_(PvZ2)
# 3. Wall-nut: https://plantsvszombies.fandom.com/wiki/Wall-nut_(PvZ2)
# 4. Potato Mine: https://plantsvszombies.fandom.com/wiki/Potato_Mine_(PvZ2)
# 5. Cabbage-pult: https://plantsvszombies.fandom.com/wiki/Cabbage-pult_(PvZ2)
# 6. Bloomerang: https://plantsvszombies.fandom.com/wiki/Bloomerang_(PvZ2)
# 7. Iceberg Lettuce: https://plantsvszombies.fandom.com/wiki/Iceberg_Lettuce
# 8. Grave Buster: https://plantsvszombies.fandom.com/wiki/Grave_Buster_(PvZ2)
# 9. Bonk Choy: https://plantsvszombies.fandom.com/wiki/Bonk_Choy_(PvZ2)
# 10. Repeater: https://plantsvszombies.fandom.com/wiki/Repeater_(PvZ2)
# 11. Twin Sunflower: https://plantsvszombies.fandom.com/wiki/Twin_Sunflower_(PvZ2)
# 12. Kernel-pult: https://plantsvszombies.fandom.com/wiki/Kernel-pult_(PvZ2)
# 13. Snapdragon: https://plantsvszombies.fandom.com/wiki/Snapdragon_(PvZ2)
# 14. Spikeweed: https://plantsvszombies.fandom.com/wiki/Spikeweed_(PvZ2)
# 15. Spring Bean: https://plantsvszombies.fandom.com/wiki/Spring_Bean
# 16. Coconut Cannon: https://plantsvszombies.fandom.com/wiki/Coconut_Cannon_(PvZ2)
# 17. Threepeater: https://plantsvszombies.fandom.com/wiki/Threepeater_(PvZ2)
# 18. Spikerock: https://plantsvszombies.fandom.com/wiki/Spikerock_(PvZ2)
# 19. Cherry Bomb: https://plantsvszombies.fandom.com/wiki/Cherry_Bomb_(PvZ2)
# 20. Split Pea: https://plantsvszombies.fandom.com/wiki/Split_Pea_(PvZ2)
# 21. Chili Bean: https://plantsvszombies.fandom.com/wiki/Chili_Bean
# 22. Pea Pod: https://plantsvszombies.fandom.com/wiki/Pea_Pod
# 23. Lightning Reed: https://plantsvszombies.fandom.com/wiki/Lightning_Reed_(PvZ2)
# 24. Melon-pult: https://plantsvszombies.fandom.com/wiki/Melon-pult_(PvZ2)
# 25. Tall-nut: https://plantsvszombies.fandom.com/wiki/Tall-nut_(PvZ2)
# 26. Winter Melon: https://plantsvszombies.fandom.com/wiki/Winter_Melon_(PvZ2)
# 27. Hot Potato: https://plantsvszombies.fandom.com/wiki/Hot_Potato
# 28. Pepper-pult: https://plantsvszombies.fandom.com/wiki/Pepper-pult
# 29. Chard Guard: https://plantsvszombies.fandom.com/wiki/Chard_Guard
# 30. Stunion: https://plantsvszombies.fandom.com/wiki/Stunion
# 31. Rotobaga: https://plantsvszombies.fandom.com/wiki/Rotobaga
# 32. Red Stinger: https://plantsvszombies.fandom.com/wiki/Red_Stinger_(PvZ2)
# 33. A.K.E.E.: https://plantsvszombies.fandom.com/wiki/A.K.E.E.
# 34. Endurian: https://plantsvszombies.fandom.com/wiki/Endurian_(PvZ2)
# 35. Stallia: https://plantsvszombies.fandom.com/wiki/Stallia
# 36. Gold Leaf: https://plantsvszombies.fandom.com/wiki/Gold_Leaf
# 37. Laser Bean: https://plantsvszombies.fandom.com/wiki/Laser_Bean_(PvZ2)
# 38. Blover: https://plantsvszombies.fandom.com/wiki/Blover_(PvZ2)
# 39. Citron: https://plantsvszombies.fandom.com/wiki/Citron_(PvZ2)
# 40. E.M.Peach: https://plantsvszombies.fandom.com/wiki/E.M.Peach_(PvZ2)
# 41. Infi-nut: https://plantsvszombies.fandom.com/wiki/Infi-nut
# 42. Magnifying Grass: https://plantsvszombies.fandom.com/wiki/Magnifying_Grass_(PvZ2)
# 43. Tile Turnip: https://plantsvszombies.fandom.com/wiki/Tile_Turnip
# 44. Sun-shroom: https://plantsvszombies.fandom.com/wiki/Sun-shroom_(PvZ2)
# 45. Puff-shroom: https://plantsvszombies.fandom.com/wiki/Puff-shroom_(PvZ2)
# 46. Fume-shroom: https://plantsvszombies.fandom.com/wiki/Fume-shroom_(PvZ2)
# 47. Sun Bean: https://plantsvszombies.fandom.com/wiki/Sun_Bean
# 48. Magnet-shroom: https://plantsvszombies.fandom.com/wiki/Magnet-shroom_(PvZ2)
# 49. Phat Beet: https://plantsvszombies.fandom.com/wiki/Phat_Beet
# 50. Celery Stalker: https://plantsvszombies.fandom.com/wiki/Celery_Stalker
# 51. Thyme Warp: https://plantsvszombies.fandom.com/wiki/Thyme_Warp
# 52. Garlic: https://plantsvszombies.fandom.com/wiki/Garlic_(PvZ2)
# 53. Spore-shroom: https://plantsvszombies.fandom.com/wiki/Spore-shroom
# 54. Intensive Carrot: https://plantsvszombies.fandom.com/wiki/Intensive_Carrot
# 55. Primal Peashooter: https://plantsvszombies.fandom.com/wiki/Primal_Peashooter
# 56. Primal Wall-nut: https://plantsvszombies.fandom.com/wiki/Primal_Wall-nut
# 57. Perfume-shroom: https://plantsvszombies.fandom.com/wiki/Perfume-shroom
# 58. Primal Sunflower: https://plantsvszombies.fandom.com/wiki/Primal_Sunflower
# 59. Primal Potato Mine: https://plantsvszombies.fandom.com/wiki/Primal_Potato_Mine
# 60. Lily Pad: https://plantsvszombies.fandom.com/wiki/Lily_Pad_(PvZ2)
# 61. Tangle Kelp: https://plantsvszombies.fandom.com/wiki/Tangle_Kelp_(PvZ2)
# 62. Bowling Bulb: https://plantsvszombies.fandom.com/wiki/Bowling_Bulb
# 63. Guacodile: https://plantsvszombies.fandom.com/wiki/Guacodile
# 64. Banana Launcher: https://plantsvszombies.fandom.com/wiki/Banana_Launcher
# 65. Moonflower: https://plantsvszombies.fandom.com/wiki/Moonflower
# 66. Nightshade: https://plantsvszombies.fandom.com/wiki/Nightshade
# 67. Shadow-shroom: https://plantsvszombies.fandom.com/wiki/Shadow-shroom
# 68. Dusk Lobber: https://plantsvszombies.fandom.com/wiki/Dusk_Lobber
# 69. Grimrose: https://plantsvszombies.fandom.com/wiki/Grimrose
# 70. Snow Pea: https://plantsvszombies.fandom.com/wiki/Snow_Pea_(PvZ2)
# 71. Power Lily: https://plantsvszombies.fandom.com/wiki/Power_Lily
# 72. Imitater: https://plantsvszombies.fandom.com/wiki/Imitater_(PvZ2)
# 73. Chomper: https://plantsvszombies.fandom.com/wiki/Chomper_(PvZ2)
# 74. Toadstool: https://plantsvszombies.fandom.com/wiki/Toadstool
# 75. Strawburst: https://plantsvszombies.fandom.com/wiki/Strawburst
# 76. Cactus: https://plantsvszombies.fandom.com/wiki/Cactus_(PvZ2)
# 77. Electric Blueberry: https://plantsvszombies.fandom.com/wiki/Electric_Blueberry
# 78. Jack O' Lantern: https://plantsvszombies.fandom.com/wiki/Jack_O%27_Lantern
# 79. Grapeshot: https://plantsvszombies.fandom.com/wiki/Grapeshot
# 80. Cold Snapdragon: https://plantsvszombies.fandom.com/wiki/Cold_Snapdragon
# 81. Escape Root: https://plantsvszombies.fandom.com/wiki/Escape_Root
# 82. Gold Bloom: https://plantsvszombies.fandom.com/wiki/Gold_Bloom
# 83. Wasabi Whip: https://plantsvszombies.fandom.com/wiki/Wasabi_Whip
# 84. Kiwibeast: https://plantsvszombies.fandom.com/wiki/Kiwibeast
# 85. Apple Mortar: https://plantsvszombies.fandom.com/wiki/Apple_Mortar
# 86. Witch Hazel: https://plantsvszombies.fandom.com/wiki/Witch_Hazel_(PvZ2)
# 87. Parsnip: https://plantsvszombies.fandom.com/wiki/Parsnip
# 88. Missile Toe: https://plantsvszombies.fandom.com/wiki/Missile_Toe
# 89. Caulipower: https://plantsvszombies.fandom.com/wiki/Caulipower
# 90. Electric Peashooter: https://plantsvszombies.fandom.com/wiki/Electric_Peashooter
# 91. Holly Barrier: https://plantsvszombies.fandom.com/wiki/Holly_Barrier
# 92. Squash: https://plantsvszombies.fandom.com/wiki/Squash_(PvZ2)
# 93. Jalapeno: https://plantsvszombies.fandom.com/wiki/Jalapeno_(PvZ2)
# 94. Hypno-shroom: https://plantsvszombies.fandom.com/wiki/Hypno-shroom_(PvZ2)
# 95. Pea-nut: https://plantsvszombies.fandom.com/wiki/Pea-nut
# 96. Homing Thistle: https://plantsvszombies.fandom.com/wiki/Homing_Thistle
# 97. Ghost Pepper: https://plantsvszombies.fandom.com/wiki/Ghost_Pepper
# 98. Sweet Potato: https://plantsvszombies.fandom.com/wiki/Sweet_Potato_(PvZ2)
# 99. Sap-fling: https://plantsvszombies.fandom.com/wiki/Sap-fling
# 100. Hurrikale: https://plantsvszombies.fandom.com/wiki/Hurrikale
# 101. Fire Peashooter: https://plantsvszombies.fandom.com/wiki/Fire_Peashooter_(PvZ2)
# 102. Lava Guava: https://plantsvszombies.fandom.com/wiki/Lava_Guava
# 103. Shrinking Violet: https://plantsvszombies.fandom.com/wiki/Shrinking_Violet
# 104. Electric Currant: https://plantsvszombies.fandom.com/wiki/Electric_Currant
# 105. Fila-mint: https://plantsvszombies.fandom.com/wiki/Fila-mint
# 106. Pepper-mint: https://plantsvszombies.fandom.com/wiki/Pepper-mint
# 107. Winter-mint: https://plantsvszombies.fandom.com/wiki/Winter-mint
# 108. Reinforce-mint: https://plantsvszombies.fandom.com/wiki/Reinforce-mint
# 109. Bombard-mint: https://plantsvszombies.fandom.com/wiki/Bombard-mint
# 110. Ail-mint: https://plantsvszombies.fandom.com/wiki/Ail-mint
# 111. Enchant-mint: https://plantsvszombies.fandom.com/wiki/Enchant-mint
# 112. Contain-mint: https://plantsvszombies.fandom.com/wiki/Contain-mint
# 113. Enforce-mint: https://plantsvszombies.fandom.com/wiki/Enforce-mint
# 114. Arma-mint: https://plantsvszombies.fandom.com/wiki/Arma-mint
# 115. Conceal-mint: https://plantsvszombies.fandom.com/wiki/Conceal-mint
# 116. Spear-mint: https://plantsvszombies.fandom.com/wiki/Spear-mint
# 117. Appease-mint: https://plantsvszombies.fandom.com/wiki/Appease-mint
# 118. Torchwood: https://plantsvszombies.fandom.com/wiki/Torchwood_(PvZ2)
# 119. Starfruit: https://plantsvszombies.fandom.com/wiki/Starfruit_(PvZ2)
# 120. Dandelion: https://plantsvszombies.fandom.com/wiki/Dandelion_(PvZ2)
# 121. Blooming Heart: https://plantsvszombies.fandom.com/wiki/Blooming_Heart
# 122. Bombegranate: https://plantsvszombies.fandom.com/wiki/Bombegranate
# 123. Explode-O-Nut: https://plantsvszombies.fandom.com/wiki/Explode-O-Nut_(PvZ2)
# 124. Aloe: https://plantsvszombies.fandom.com/wiki/Aloe
# 125. Hot Date: https://plantsvszombies.fandom.com/wiki/Hot_Date
# 126. Solar Tomato: https://plantsvszombies.fandom.com/wiki/Solar_Tomato
# 127. Enlighten-mint: https://plantsvszombies.fandom.com/wiki/Enlighten-mint
# 128. Shadow Peashooter: https://plantsvszombies.fandom.com/wiki/Shadow_Peashooter
# 129. Goo Peashooter: https://plantsvszombies.fandom.com/wiki/Goo_Peashooter
# 130. Sling Pea: https://plantsvszombies.fandom.com/wiki/Sling_Pea
# 131. Snap Pea: https://plantsvszombies.fandom.com/wiki/Snap_Pea
# 132. Zoybean Pod: https://plantsvszombies.fandom.com/wiki/Zoybean_Pod
# 133. Electrici-tea: https://plantsvszombies.fandom.com/wiki/Electrici-tea
# 134. Dazey Chain: https://plantsvszombies.fandom.com/wiki/Dazey_Chain
# 135. Blastberry Vine: https://plantsvszombies.fandom.com/wiki/Blastberry_Vine
# 136. Pokra: https://plantsvszombies.fandom.com/wiki/Pokra
# 137. Imp Pear: https://plantsvszombies.fandom.com/wiki/Imp_Pear
# 138. Pyre Vine: https://plantsvszombies.fandom.com/wiki/Pyre_Vine
# 139. Pumpkin: https://plantsvszombies.fandom.com/wiki/Pumpkin_(PvZ2)
# 140. Ice Bloom: https://plantsvszombies.fandom.com/wiki/Ice_Bloom
# 141. Dartichoke: https://plantsvszombies.fandom.com/wiki/Dartichoke
# 142. Ultomato: https://plantsvszombies.fandom.com/wiki/Ultomato
# 143. Gumnut: https://plantsvszombies.fandom.com/wiki/Gumnut
# 144. Shine Vine: https://plantsvszombies.fandom.com/wiki/Shine_Vine
# 145. Tumbleweed: https://plantsvszombies.fandom.com/wiki/Tumbleweed
# 146. Olive Pit: https://plantsvszombies.fandom.com/wiki/Olive_Pit
# 147. Puffball: https://plantsvszombies.fandom.com/wiki/Puffball
# 148. Explode-o-Vine: https://plantsvszombies.fandom.com/wiki/Explode-o-Vine
# 149. Murkadamia Nut: https://plantsvszombies.fandom.com/wiki/Murkadamia_Nut
# 150. Turkey-pult: https://plantsvszombies.fandom.com/wiki/Turkey-pult
# 151. Headbutter Lettuce: https://plantsvszombies.fandom.com/wiki/Headbutter_Lettuce
# 152. Boingsetta: https://plantsvszombies.fandom.com/wiki/Boingsetta
# 153. Stickybomb Rice: https://plantsvszombies.fandom.com/wiki/Stickybomb_Rice
# 154. Hocus Crocus: https://plantsvszombies.fandom.com/wiki/Hocus_Crocus
# 155. Gloom Vine: https://plantsvszombies.fandom.com/wiki/Gloom_Vine
# 156. Draftodil: https://plantsvszombies.fandom.com/wiki/Draftodil
# 157. Boom Balloon Flower: https://plantsvszombies.fandom.com/wiki/Boom_Balloon_Flower
# 158. Pea Vine: https://plantsvszombies.fandom.com/wiki/Pea_Vine
# 159. Inferno: https://plantsvszombies.fandom.com/wiki/Inferno
# 160. Solar Sage: https://plantsvszombies.fandom.com/wiki/Solar_Sage
# 161. Power Vine: https://plantsvszombies.fandom.com/wiki/Power_Vine
# 162. Noctarine: https://plantsvszombies.fandom.com/wiki/Noctarine
# 163. Heath Seeker: https://plantsvszombies.fandom.com/wiki/Heath_Seeker
# 164. Iceweed: https://plantsvszombies.fandom.com/wiki/Iceweed
# 165. Tiger Grass: https://plantsvszombies.fandom.com/wiki/Tiger_Grass
# 166. Teleportato Mine: https://plantsvszombies.fandom.com/wiki/Teleportato_Mine
# 167. Blockoli: https://plantsvszombies.fandom.com/wiki/Blockoli
# 168. Buttercup: https://plantsvszombies.fandom.com/wiki/Buttercup_(PvZ2)
# 169. Bramble Bush: https://plantsvszombies.fandom.com/wiki/Bramble_Bush
# 170. Marigold: https://plantsvszombies.fandom.com/wiki/Marigold_(PvZ2)

# %% [markdown]
# ## Beautiful Soup 4
#
# ### Step 4: Extract the Level Upgrade Table from the plant page.
#
# Next, visit the plant pages to each plant on the Chrome driver by opening the links extracted from previous step. Then, extract the HTML string for the "Level Upgrade" table from the page.
#
# > **Note:** This process takes up to 10 minutes.
#
# XPath to the Level Upgrade table on each plant page:
#
# ```
# (//*/span[(contains(text(), 'Level upgrade') or contains(text(), 'Level Upgrade')) and not(./span)]/parent::*/following-sibling::*//tr/parent::*/parent::table)[position()=1]
# ```
#
# Breakdown of each XPath component:
#
# - `//*/span[(contains(text(), 'Level upgrade') or contains(text(), 'Level Upgrade')) and not(./span)]`: The base element is a header containing the text "Level upgrade" or "Level Upgrade".
#   - Asterisk `*` is used because the header level is inconsistent (`h3` vs `h4`).
#   - The condition `not(./span)` is to filter out header texts that contains span text "(China only)", since we are scraping Level Upgrade table for international version gameplay.
# - `/parent::*/following-sibling::*`: Traversal to the parent element and its successors. The table element is the immediate, or the child of the immediate successor element.
# - `//tr/parent::*/parent::table`: Traversal to the `table` element from the `tr` element. At this stage, the XPath might return multiple `table` elements (including the targeted Level Upgraded table).
# - `(<Some XPath>)[position()=1]`: Specify that we want **the first table** satisfying the specified attributes, and thus will be returned with the provided XPath.

# %%
# %%time

plant_page_sources = []

for name, link in zip(plant_names, plant_page_links):
    driver.get(link)
    try:
        table_elem = driver.find_element(By.XPATH, "(//*/span[(contains(text(), 'Level upgrade') or contains(text(), 'Level Upgrade')) and not(./span)]/parent::*/following-sibling::*//tr/parent::*/parent::table)[position()=1]")
        table_html = table_elem.get_attribute('innerHTML')
    except:
        print("Plant w/o Level Upgrade table:", name)
        table_html = ''
    plant_page_sources.append(BeautifulSoup(table_html, 'html.parser'))
    
print("\nSuccess!")
# Out:
# Plant w/o Level Upgrade table: Gold Leaf
# Plant w/o Level Upgrade table: Tile Turnip
# Plant w/o Level Upgrade table: Thyme Warp
# Plant w/o Level Upgrade table: Imitater
# Plant w/o Level Upgrade table: Marigold
#
# Success!
# Wall time: 4min 6s

# %% [markdown]
# **Note:** Except **Tile Turnip**, plants without family (Imitator, Thyme Warp, Gold Leaf, Marigold) are plants without level upgrade table.

# %% [markdown]
# Now, we have a quick look at the HTML version of the Level Upgrade table for selected plant extracted from the cell above.

# %%
# INDEX = 7 # Grave Buster
# INDEX = 167 # Buttercup - unnamed column
INDEX = 100 # Fire Peashooter - extra row.
# INDEX = 138 # Pumpkin - extra row.
# INDEX = 1 # Sunflower - unnamed column
# # INDEX = 2 # Wall-nut - unnamed column
# INDEX = 104 # Fila-mint
# INDEX = 85 # Witch hazel
# INDEX = 84 # apple mortar
# INDEX = 15 # Coconut cannon
# INDEX = 80 # Escape root

print(f"Plant: {plant_names[INDEX]}\n\nPrinting HTML Level Upgrade table...")
print("-"*50)
print(plant_page_sources[INDEX])
# Out:
# Plant: Fire Peashooter
#
# Printing HTML Level Upgrade table...
# --------------------------------------------------
#
# <tbody><tr>
# <th rowspan="3" style="text-align: center;">Level
# </th>
# <th rowspan="3" style="text-align: center;">Seed packets
# </th>
# <th rowspan="3" style="text-align: center;">Coins
# </th>
# <th colspan="9" style="text-align: center;">Upgrades
# </th></tr>
# <tr>
# <th rowspan="2" style="text-align: center;">Sun Cost
# </th>
# <th rowspan="2" style="text-align: center;">Recharge<br/>(Fast)
# </th>
# <th rowspan="2" style="text-align: center;">Toughness<br/>(Typical)
# </th>
# <th rowspan="2" style="text-align: center;">Damage<br/>(Moderate)*
# </th>
# <th rowspan="2" style="text-align: center;">Projectile<br/>Velocity
# </th>
# <th rowspan="2" style="text-align: center;">Plant Food Power<br/>(Damage)**
# </th>
# <th colspan="2" style="text-align: center;">Special<br/>(Plasma Pea)***
# </th>
# <th rowspan="2" style="text-align: center;">Range
# </th></tr>
# <tr>
# <th style="text-align: center;">Chance
# </th>
# <th style="text-align: center;">Damage
# </th></tr>
# <tr>
# <td style="text-align: center;"><b><font color="bronze">1</font></b>
# </td>
# <td style="text-align: center;">0
# </td>
# <td style="text-align: center;">0
# </td>
# <td style="text-align: center;">175
# </td>
# <td style="text-align: center;">5 seconds
# </td>
# <td style="text-align: center;">300 <a href="/wiki/Damage_per_shot" title="Damage per shot">dps</a>
# </td>
# <td style="text-align: center;">40 dps
# </td>
# <td rowspan="2" style="text-align: center;">Normal
# </td>
# <td style="text-align: center;">225 dps
# </td>
# <td rowspan="4" style="text-align: center;">0%
# </td>
# <td rowspan="4" style="text-align: center;">N/A
# </td>
# <td rowspan="11" style="text-align: center;">Straight
# </td></tr>
# <tr>
# <td style="text-align: center;"><b><font color="bronze">2</font></b>
# </td>
# <td style="text-align: center;">10
# </td>
# <td style="text-align: center;">1,000
# </td>
# <td style="text-align: center;">175
# </td>
# <td style="text-align: center;">5 seconds
# </td>
# <td style="text-align: center;">350 dps
# </td>
# <td style="text-align: center;">60 dps
# </td>
# <td style="text-align: center;">225 dps
# </td></tr>
# <tr>
# <td style="text-align: center;"><b><font color="silver">3</font></b>
# </td>
# <td style="text-align: center;">25
# </td>
# <td style="text-align: center;">2,500
# </td>
# <td style="text-align: center;">175
# </td>
# <td style="text-align: center;">4.5 seconds
# </td>
# <td style="text-align: center;">400 dps
# </td>
# <td style="text-align: center;">80 dps
# </td>
# <td rowspan="4" style="text-align: center;">+ 1.6x
# </td>
# <td style="text-align: center;">250 dps
# </td></tr>
# <tr>
# <td style="text-align: center;"><b><font color="silver">4</font></b>
# </td>
# <td style="text-align: center;">50
# </td>
# <td style="text-align: center;">5,000
# </td>
# <td style="text-align: center;">175
# </td>
# <td style="text-align: center;">4.5 seconds
# </td>
# <td style="text-align: center;">450 dps
# </td>
# <td style="text-align: center;">100 dps
# </td>
# <td style="text-align: center;">250 dps
# </td></tr>
# <tr>
# <td style="text-align: center;"><b><font color="silver">5</font></b>
# </td>
# <td style="text-align: center;">100
# </td>
# <td style="text-align: center;">10,000
# </td>
# <td style="text-align: center;">175
# </td>
# <td style="text-align: center;">4 seconds
# </td>
# <td style="text-align: center;">550 dps
# </td>
# <td style="text-align: center;">120 dps
# </td>
# <td style="text-align: center;">250 dps
# </td>
# <td style="text-align: center;">5%
# </td>
# <td style="text-align: center;">180 dps
# </td></tr>
# <tr>
# <td style="text-align: center;"><b><font color="silver">6</font></b>
# </td>
# <td style="text-align: center;">200
# </td>
# <td style="text-align: center;">20,000
# </td>
# <td style="text-align: center;">150
# </td>
# <td style="text-align: center;">4 seconds
# </td>
# <td style="text-align: center;">600 dps
# </td>
# <td style="text-align: center;">140 dps
# </td>
# <td style="text-align: center;">275 dps
# </td>
# <td style="text-align: center;">5%
# </td>
# <td style="text-align: center;">210 dps
# </td></tr>
# <tr>
# <td style="text-align: center;"><b><font color="gold">7</font></b>
# </td>
# <td style="text-align: center;">400
# </td>
# <td style="text-align: center;">30,000
# </td>
# <td style="text-align: center;">150
# </td>
# <td style="text-align: center;">3.5 seconds
# </td>
# <td style="text-align: center;">650 dps
# </td>
# <td style="text-align: center;">160 dps
# </td>
# <td rowspan="4" style="text-align: center;">+ 2.2x
# </td>
# <td style="text-align: center;">275 dps
# </td>
# <td style="text-align: center;">10%
# </td>
# <td style="text-align: center;">240 dps
# </td></tr>
# <tr>
# <td style="text-align: center;"><b><font color="gold">8</font></b>
# </td>
# <td style="text-align: center;">800
# </td>
# <td style="text-align: center;">50,000
# </td>
# <td style="text-align: center;">150
# </td>
# <td style="text-align: center;">3.5 seconds
# </td>
# <td style="text-align: center;">700 dps
# </td>
# <td style="text-align: center;">180 dps
# </td>
# <td style="text-align: center;">275 dps
# </td>
# <td style="text-align: center;">15%
# </td>
# <td style="text-align: center;">270 dps
# </td></tr>
# <tr>
# <td style="text-align: center;"><b><font color="gold">9</font></b>
# </td>
# <td style="text-align: center;">1,200
# </td>
# <td style="text-align: center;">75,000
# </td>
# <td style="text-align: center;">150
# </td>
# <td style="text-align: center;">3 seconds
# </td>
# <td style="text-align: center;">800 dps
# </td>
# <td style="text-align: center;">200 dps
# </td>
# <td style="text-align: center;">300 dps
# </td>
# <td style="text-align: center;">20%
# </td>
# <td style="text-align: center;">300 dps
# </td></tr>
# <tr>
# <td style="text-align: center;"><b><font color="gold">10</font></b>
# </td>
# <td style="text-align: center;">1,600
# </td>
# <td style="text-align: center;">100,000
# </td>
# <td style="text-align: center;">125
# </td>
# <td style="text-align: center;">3 seconds
# </td>
# <td style="text-align: center;">900 dps
# </td>
# <td style="text-align: center;">240 dps
# </td>
# <td style="text-align: center;">300 dps
# </td>
# <td style="text-align: center;">25%
# </td>
# <td style="text-align: center;">330 dps
# </td></tr></tbody>

# %% [markdown]
# ## Pandas
#
# ### Step 5: Load Level Upgrade Table into `pandas` data frame.
#
# Using Python's `pandas` package, we can load an HTML table into a `pandas` data frame. To do so, we define a helper function: `get_raw_level_upgrade_table()` which returns the raw version of the HTML table loaded as a `pandas` data frame.
#
# In the function declaration, the line
#
# ```
# pd.read_html(html_str)[0]
# ```
#
# indicates that we are only interested in **the first value** returned from the `pd.read_html()` method. This is because the `pd.read_html()` method searches for all table elements from the HTML string passed into the method, then returns a list of data frames converted from these HTML tables. In this case, the HTML string only consists of Level Upgrade table, which is already pre-selected during **Step 4**.
#
# Other example of `pd.read_html()`: https://pbpython.com/pandas-html-table.html

# %%
# Helper function #1
def get_raw_level_upgrade_table(index, name, soup):
    html_str = f"<table>{soup[index]}</table>"
    return pd.read_html(html_str, keep_default_na=False, na_values=[''])[0]

# Test helper function
level_upgrade_table = get_raw_level_upgrade_table(INDEX, plant_names, plant_page_sources)
display(level_upgrade_table)

print("Success!")
# Out:
#        Level Seed packets     Coins Upgrades                 \
#        Level Seed packets     Coins Sun Cost Recharge(Fast)
#        Level Seed packets     Coins Sun Cost Recharge(Fast)
# 0          1          0.0       0.0    175.0      5 seconds
# 1          2         10.0    1000.0    175.0      5 seconds
# 2          3         25.0    2500.0    175.0    4.5 seconds
# 3          4         50.0    5000.0    175.0    4.5 seconds
# 4          5        100.0   10000.0    175.0      4 seconds
# 5          6        200.0   20000.0    150.0      4 seconds
# 6          7        400.0   30000.0    150.0    3.5 seconds
# 7          8        800.0   50000.0    150.0    3.5 seconds
# 8          9       1200.0   75000.0    150.0      3 seconds
# 9         10       1600.0  100000.0    125.0      3 seconds
# 10  Straight          NaN       NaN      NaN            NaN
#
#                                                             \
#    Toughness(Typical) Damage(Moderate)* ProjectileVelocity
#    Toughness(Typical) Damage(Moderate)* ProjectileVelocity
# 0             300 dps            40 dps             Normal
# 1             350 dps            60 dps             Normal
# 2             400 dps            80 dps             + 1.6x
# 3             450 dps           100 dps             + 1.6x
# 4             550 dps           120 dps             + 1.6x
# 5             600 dps           140 dps             + 1.6x
# 6             650 dps           160 dps             + 2.2x
# 7             700 dps           180 dps             + 2.2x
# 8             800 dps           200 dps             + 2.2x
# 9             900 dps           240 dps             + 2.2x
# 10                NaN               NaN                NaN
#
#
#    Plant Food Power(Damage)** Special(Plasma Pea)***              Range
#    Plant Food Power(Damage)**                 Chance   Damage     Range
# 0                     225 dps                     0%      N/A  Straight
# 1                     225 dps                     0%      N/A  Straight
# 2                     250 dps                     0%      N/A  Straight
# 3                     250 dps                     0%      N/A  Straight
# 4                     250 dps                     5%  180 dps  Straight
# 5                     275 dps                     5%  210 dps  Straight
# 6                     275 dps                    10%  240 dps  Straight
# 7                     275 dps                    15%  270 dps  Straight
# 8                     300 dps                    20%  300 dps  Straight
# 9                     300 dps                    25%  330 dps  Straight
# 10                        NaN                    NaN      NaN       NaN
# Success!

# %% [markdown]
# ### Step 6: Flatten column values in the Level Upgrade Table.
#
# For Level Upgrade tables, the columns are multiindex. This can be further verified using the following line of code:
#
# ```
# level_upgrade_table.columns.values
# ```

# %%
level_upgrade_table.columns.values
# Out:
# array([('Level', 'Level', 'Level'),
#        ('Seed packets', 'Seed packets', 'Seed packets'),
#        ('Coins', 'Coins', 'Coins'), ('Upgrades', 'Sun Cost', 'Sun Cost'),
#        ('Upgrades', 'Recharge(Fast)', 'Recharge(Fast)'),
#        ('Upgrades', 'Toughness(Typical)', 'Toughness(Typical)'),
#        ('Upgrades', 'Damage(Moderate)*', 'Damage(Moderate)*'),
#        ('Upgrades', 'ProjectileVelocity', 'ProjectileVelocity'),
#        ('Upgrades', 'Plant Food Power(Damage)**', 'Plant Food Power(Damage)**'),
#        ('Upgrades', 'Special(Plasma Pea)***', 'Chance'),
#        ('Upgrades', 'Special(Plasma Pea)***', 'Damage'),
#        ('Upgrades', 'Range', 'Range')], dtype=object)

# %% [markdown]
# We define a helper function: `flatten_multiindex_column()` to flatten the multiindex columns. The underscore "-" character is not only used to join the column values at different levels, but also to replace special characters on the column names.
#
# > **Note:** There is no treatment on [camelCase](https://en.wikipedia.org/wiki/Camel_case) column names.
#
# Further reading on flattening multiindex column names: https://stackoverflow.com/questions/14507794/pandas-how-to-flatten-a-hierarchical-index-in-columns

# %%
# Helper function #2
# ... ignore camelCase for now.
def flatten_multiindex_column(column_value):
    prev_col = ''
    col_to_flatten = list()

    # Remove duplicates
    for c in column_value:
        if prev_col == c:
            break
            
        prev_col = c
        col_to_flatten.append(c)
    
    # Join column values from different levels
    new_col = ' '.join(col_to_flatten)
    
    # Replace space and special characters using underscore "_"
    new_col = ''.join([ch if ch.isalpha() else ' ' for ch in new_col]).strip().replace(' ', '_')
    while '__' in new_col:
        new_col = new_col.replace('__', '_')

    # Lowercase new column name
    return new_col.lower()

# %% [markdown]
# Apply helper function to flatten the multiindex columns. Then, print the level upgrade table with flattened columns.

# %%
# Test helper function
level_upgrade_table.columns = list(map(flatten_multiindex_column, level_upgrade_table.columns.values))

print(f"Plant: {plant_names[INDEX]}\n{'-'*50}")
display(level_upgrade_table)

print("Success!")
# Out:
# Plant: Fire Peashooter
# --------------------------------------------------
#        level  seed_packets     coins  upgrades_sun_cost  \
# 0          1           0.0       0.0              175.0
# 1          2          10.0    1000.0              175.0
# 2          3          25.0    2500.0              175.0
# 3          4          50.0    5000.0              175.0
# 4          5         100.0   10000.0              175.0
# 5          6         200.0   20000.0              150.0
# 6          7         400.0   30000.0              150.0
# 7          8         800.0   50000.0              150.0
# 8          9        1200.0   75000.0              150.0
# 9         10        1600.0  100000.0              125.0
# 10  Straight           NaN       NaN                NaN
#
#    upgrades_recharge_fast upgrades_toughness_typical upgrades_damage_moderate  \
# 0               5 seconds                    300 dps                   40 dps
# 1               5 seconds                    350 dps                   60 dps
# 2             4.5 seconds                    400 dps                   80 dps
# 3             4.5 seconds                    450 dps                  100 dps
# 4               4 seconds                    550 dps                  120 dps
# 5               4 seconds                    600 dps                  140 dps
# 6             3.5 seconds                    650 dps                  160 dps
# 7             3.5 seconds                    700 dps                  180 dps
# 8               3 seconds                    800 dps                  200 dps
# 9               3 seconds                    900 dps                  240 dps
# 10                    NaN                        NaN                      NaN
#
#    upgrades_projectilevelocity upgrades_plant_food_power_damage  \
# 0                       Normal                          225 dps
# 1                       Normal                          225 dps
# 2                       + 1.6x                          250 dps
# 3                       + 1.6x                          250 dps
# 4                       + 1.6x                          250 dps
# 5                       + 1.6x                          275 dps
# 6                       + 2.2x                          275 dps
# 7                       + 2.2x                          275 dps
# 8                       + 2.2x                          300 dps
# 9                       + 2.2x                          300 dps
# 10                         NaN                              NaN
#
#    upgrades_special_plasma_pea_chance upgrades_special_plasma_pea_damage  \
# 0                                  0%                                N/A
# 1                                  0%                                N/A
# 2                                  0%                                N/A
# 3                                  0%                                N/A
# 4                                  5%                            180 dps
# 5                                  5%                            210 dps
# 6                                 10%                            240 dps
# 7                                 15%                            270 dps
# 8                                 20%                            300 dps
# 9                                 25%                            330 dps
# 10                                NaN                                NaN
#
#    upgrades_range
# 0        Straight
# 1        Straight
# 2        Straight
# 3        Straight
# 4        Straight
# 5        Straight
# 6        Straight
# 7        Straight
# 8        Straight
# 9        Straight
# 10            NaN
# Success!

# %% [markdown]
# The Level Upgrade table (data frame) is now updated with flattened column name. This helps us further preprocess the data frame more easily.
#
# ### Step 7: Remove unnecessary rows or columns due to wrong values specified in `rowspan` or `colspan` of the HTML table.
#
# In this section, we define two helper functions. The first helper function `remove_na_rows_and_unnamed_cols()` removes unnecessary rows and columns in the data frame containing `NaN` values. The function definition can be found below.
#
# ### Step 8: Identify columns with should be converted to numeric data types.
#
# Next, inspect the data types of each column in the Level Upgrade table.

# %%
# Before conversion
level_upgrade_table.dtypes
# Out:
# level                                  object
# seed_packets                          float64
# coins                                 float64
# upgrades_sun_cost                     float64
# upgrades_recharge_fast                 object
# upgrades_toughness_typical             object
# upgrades_damage_moderate               object
# upgrades_projectilevelocity            object
# upgrades_plant_food_power_damage       object
# upgrades_special_plasma_pea_chance     object
# upgrades_special_plasma_pea_damage     object
# upgrades_range                         object
# dtype: object

# %% [markdown]
# The second helper function: `get_new_col_dtypes()` helps identify all columns which should be stored as numeric values (columns with seconds and dps - damage per shot).
#
# > **Note:** For `get_new_col_dtypes()`, the columns that should be converted to numeric types are determined by the **first records** (which is Level 1). This is a simplified assumption, which is not applicable for cases when special effects with damages are added after upgrading certain plants.

# %%
# Helper function #3a
def remove_na_rows_and_unnamed_cols(df):
    # Remove unnamed columns
    cols = [val for val in df.columns.values if 'unnamed' not in val]
    new_df = df.copy()[cols]
    
    # Remove rows that contains NA
    new_df = new_df.dropna()
    
    return new_df

# Test helper function
display(remove_na_rows_and_unnamed_cols(level_upgrade_table))


# Helper function #3b
# Identify columns which need to be converted to numeric value.
# ... second -> float; dps -> int.
def get_new_col_dtypes(df):
    dict_col = dict()

    # Get first row of the table.
    for i, val in enumerate(df.head(1).values[0]):
        if 'second' in str(val):
            dict_col[i] = (f"{df.columns.values[i]}_in_sec", 'float')

        if 'dps' in str(val):
            dict_col[i] = (f"{df.columns.values[i]}_in_dps", 'int')

    return dict_col

# Test helper function
level_upgrade_table = remove_na_rows_and_unnamed_cols(level_upgrade_table)
dict_new_col_dtypes = get_new_col_dtypes(level_upgrade_table)
display(dict_new_col_dtypes)

print("Success!")
# Out:
#   level  seed_packets     coins  upgrades_sun_cost upgrades_recharge_fast  \
# 0     1           0.0       0.0              175.0              5 seconds
# 1     2          10.0    1000.0              175.0              5 seconds
# 2     3          25.0    2500.0              175.0            4.5 seconds
# 3     4          50.0    5000.0              175.0            4.5 seconds
# 4     5         100.0   10000.0              175.0              4 seconds
# 5     6         200.0   20000.0              150.0              4 seconds
# 6     7         400.0   30000.0              150.0            3.5 seconds
# 7     8         800.0   50000.0              150.0            3.5 seconds
# 8     9        1200.0   75000.0              150.0              3 seconds
# 9    10        1600.0  100000.0              125.0              3 seconds
#
#   upgrades_toughness_typical upgrades_damage_moderate  \
# 0                    300 dps                   40 dps
# 1                    350 dps                   60 dps
# 2                    400 dps                   80 dps
# 3                    450 dps                  100 dps
# 4                    550 dps                  120 dps
# 5                    600 dps                  140 dps
# 6                    650 dps                  160 dps
# 7                    700 dps                  180 dps
# 8                    800 dps                  200 dps
# 9                    900 dps                  240 dps
#
#   upgrades_projectilevelocity upgrades_plant_food_power_damage  \
# 0                      Normal                          225 dps
# 1                      Normal                          225 dps
# 2                      + 1.6x                          250 dps
# 3                      + 1.6x                          250 dps
# 4                      + 1.6x                          250 dps
# 5                      + 1.6x                          275 dps
# 6                      + 2.2x                          275 dps
# 7                      + 2.2x                          275 dps
# 8                      + 2.2x                          300 dps
# 9                      + 2.2x                          300 dps
#
#   upgrades_special_plasma_pea_chance upgrades_special_plasma_pea_damage  \
# 0                                 0%                                N/A
# 1                                 0%                                N/A
# 2                                 0%                                N/A
# 3                                 0%                                N/A
# 4                                 5%                            180 dps
# 5                                 5%                            210 dps
# 6                                10%                            240 dps
# 7                                15%                            270 dps
# 8                                20%                            300 dps
# 9                                25%                            330 dps
#
#   upgrades_range
# 0       Straight
# 1       Straight
# 2       Straight
# 3       Straight
# 4       Straight
# 5       Straight
# 6       Straight
# 7       Straight
# 8       Straight
# 9       Straight
# {4: ('upgrades_recharge_fast_in_sec', 'float'),
#  5: ('upgrades_toughness_typical_in_dps', 'int'),
#  6: ('upgrades_damage_moderate_in_dps', 'int'),
#  8: ('upgrades_plant_food_power_damage_in_dps', 'int')}
# Success!

# %% [markdown]
# ### Step 9: Convert selected columns from string to numeric data types.
#
# The helper function `get_updated_level_upgrade_table()` is used to convert data types of the columns selected during **Step 8** using helper function `get_new_col_dtypes()`.

# %%
# Helper function #4
def get_updated_level_upgrade_table(df, dict_col):
    def get_numerics(s, type='int'):
        if ' ' in s:
            if type == 'int':
                return int(s.split(' ')[0])
            if type == 'float':
                return float(s.split(' ')[0])
        
        # Naive assumption: no other characters appear in between digits.
        if type == 'int':
            return int(''.join([ch for ch in s if ch.isnumeric()]))
        
        # Assumption: Decimal values are separated by decimal point "."
        if type == 'float':
            return float(''.join([ch for ch in s if ((ch.isnumeric()) | (ch == '.'))]))
        
        return 0
            
    get_int = lambda s: get_numerics(s, 'int')
    get_float = lambda s: get_numerics(s, 'float')
    
    for idx, (new_col, new_dtype) in dict_col.items():
        ori_col = df.columns[idx]
        df[new_col] = list(map(
            get_float if new_dtype == 'float' else get_int,
            df[ori_col]
        ))
        
    new_cols = list()
    idx_cols_to_ignore = list(dict_col.keys())

    for i, col in enumerate(df.columns):
        if i in idx_cols_to_ignore:
            continue

        new_cols.append(col)
    
    return df[new_cols]

# %% [markdown]
# Display Level Upgrade table with new column names and data types.

# %%
# Test helper function
level_upgrade_table = get_updated_level_upgrade_table(level_upgrade_table, dict_new_col_dtypes)
display(level_upgrade_table)

print("Success!")
# Out:
#   level  seed_packets     coins  upgrades_sun_cost  \
# 0     1           0.0       0.0              175.0
# 1     2          10.0    1000.0              175.0
# 2     3          25.0    2500.0              175.0
# 3     4          50.0    5000.0              175.0
# 4     5         100.0   10000.0              175.0
# 5     6         200.0   20000.0              150.0
# 6     7         400.0   30000.0              150.0
# 7     8         800.0   50000.0              150.0
# 8     9        1200.0   75000.0              150.0
# 9    10        1600.0  100000.0              125.0
#
#   upgrades_projectilevelocity upgrades_special_plasma_pea_chance  \
# 0                      Normal                                 0%
# 1                      Normal                                 0%
# 2                      + 1.6x                                 0%
# 3                      + 1.6x                                 0%
# 4                      + 1.6x                                 5%
# 5                      + 1.6x                                 5%
# 6                      + 2.2x                                10%
# 7                      + 2.2x                                15%
# 8                      + 2.2x                                20%
# 9                      + 2.2x                                25%
#
#   upgrades_special_plasma_pea_damage upgrades_range  \
# 0                                N/A       Straight
# 1                                N/A       Straight
# 2                                N/A       Straight
# 3                                N/A       Straight
# 4                            180 dps       Straight
# 5                            210 dps       Straight
# 6                            240 dps       Straight
# 7                            270 dps       Straight
# 8                            300 dps       Straight
# 9                            330 dps       Straight
#
#    upgrades_recharge_fast_in_sec  upgrades_toughness_typical_in_dps  \
# 0                            5.0                                300
# 1                            5.0                                350
# 2                            4.5                                400
# 3                            4.5                                450
# 4                            4.0                                550
# 5                            4.0                                600
# 6                            3.5                                650
# 7                            3.5                                700
# 8                            3.0                                800
# 9                            3.0                                900
#
#    upgrades_damage_moderate_in_dps  upgrades_plant_food_power_damage_in_dps
# 0                               40                                      225
# 1                               60                                      225
# 2                               80                                      250
# 3                              100                                      250
# 4                              120                                      250
# 5                              140                                      275
# 6                              160                                      275
# 7                              180                                      275
# 8                              200                                      300
# 9                              240                                      300
# Success!

# %% [markdown]
# Verify that there is no more missing values and the selected columns are converted to numeric data types successfully.

# %%
# After conversion
display(level_upgrade_table.dtypes)
# Out:
# level                                       object
# seed_packets                               float64
# coins                                      float64
# upgrades_sun_cost                          float64
# upgrades_projectilevelocity                 object
# upgrades_special_plasma_pea_chance          object
# upgrades_special_plasma_pea_damage          object
# upgrades_range                              object
# upgrades_recharge_fast_in_sec              float64
# upgrades_toughness_typical_in_dps            int64
# upgrades_damage_moderate_in_dps              int64
# upgrades_plant_food_power_damage_in_dps      int64
# dtype: object

# %% [markdown]
# ### Step 10: Save Level Upgrade table to CSV file.
#
# The data frame is saved as CSV file in the `./output/pvz2_level_upgrade` folder.

# %%
import datetime

# Helper function
def save_level_upgrade_tables_to_csv(index, name, soup):
    print(f"Plant: {name[index]}\n{'-'*50}")
    
    # Case: HTML table is not available - HTML string is empty.
    if len(soup[index]) == 0:
        print("Level upgrade table is not available :(")
        return None
    
    # Case: HTML table is available - Convert HTML to data frame.
    df = get_raw_level_upgrade_table(index, name, soup)
    df.columns = list(map(flatten_multiindex_column, df.columns.values))
    df = remove_na_rows_and_unnamed_cols(df)
    df = get_updated_level_upgrade_table(df, get_new_col_dtypes(df))
    
    # Save data frame into CSV file.
    current_dt = datetime.datetime.now()
    current_dt_str = current_dt.strftime("%Y%m%d_%H%M")
    
    new_plant_name = name[index].lower().strip()
    new_plant_name = ''.join([ch if ch.isalpha() else '_' for ch in new_plant_name])
    
    df.to_csv(f".//output//pvz2_level_upgrade//{index:03d}_{new_plant_name}_{current_dt_str}.csv", index=False)
    
    return df

# Test helper function.
display(save_level_upgrade_tables_to_csv(125, plant_names, plant_page_sources))

print("Successful!")
# Out:
# Plant: Solar Tomato
# --------------------------------------------------
#    level  seed_packets   coins  upgrades_sun_cost upgrades_area  \
# 0      1             0       0                100           3x3
# 1      2            10    1000                100           3x3
# 2      3            25    2500                100           3x3
# 3      4            50    5000                100           3x3
# 4      5           100   10000                100           3x3
# 5      6           200   20000                100           3x3
# 6      7           400   30000                100           3x3
# 7      8           800   50000                100           3x3
# 8      9          1200   75000                100           3x3
# 9     10          1600  100000                100           3x3
#
#    upgrades_recharge_sluggish_in_sec  upgrades_startingrecharge_in_sec  \
# 0                               25.0                              20.0
# 1                               24.0                              20.0
# 2                               23.0                              20.0
# 3                               22.0                              20.0
# 4                               21.0                              15.0
# 5                               20.0                              15.0
# 6                               19.0                              15.0
# 7                               18.0                              15.0
# 8                               17.0                              15.0
# 9                               16.0                              15.0
#
#    upgrades_toughness_typical_in_dps  upgrades_special_stun_in_sec  \
# 0                               3000                           8.0
# 1                               3000                           9.0
# 2                               3000                           9.0
# 3                               3000                          10.0
# 4                               3000                          10.0
# 5                               3000                          11.0
# 6                               3000                          11.0
# 7                               3000                          11.0
# 8                               3000                          12.0
# 9                               3000                          12.0
#
#    upgrades_damage_in_dps
# 0                       0
# 1                       0
# 2                     100
# 3                     100
# 4                     100
# 5                     100
# 6                     100
# 7                     100
# 8                     100
# 9                     100
# Successful!

# %% [markdown]
# ### Pandas: Summary
#
# Walk through **Steps 5 - 10** for Level Upgrade tables for all plants.

# %%
for i in range(len(plant_names)):
    try:
        save_level_upgrade_tables_to_csv(i, plant_names, plant_page_sources)
    except:
        print(f"Error loading level upgrade page for plant: {plant_names[i]}")
    print()
# Out:
# Plant: Peashooter
# --------------------------------------------------
#
# Plant: Sunflower
# --------------------------------------------------
#
# Plant: Wall-nut
# --------------------------------------------------
#
# Plant: Potato Mine
# --------------------------------------------------
#
# Plant: Cabbage-pult
# --------------------------------------------------
#
# Plant: Bloomerang
# --------------------------------------------------
#
# Plant: Iceberg Lettuce
# --------------------------------------------------
#
# Plant: Grave Buster
# --------------------------------------------------
#
# Plant: Bonk Choy
# --------------------------------------------------
#
# Plant: Repeater
# --------------------------------------------------
#
# Plant: Twin Sunflower
# --------------------------------------------------
#
# Plant: Kernel-pult
# --------------------------------------------------
#
# Plant: Snapdragon
# --------------------------------------------------
#
# Plant: Spikeweed
# --------------------------------------------------
#
# Plant: Spring Bean
# --------------------------------------------------
#
# Plant: Coconut Cannon
# --------------------------------------------------
#
# Plant: Threepeater
# --------------------------------------------------
#
# Plant: Spikerock
# --------------------------------------------------
#
# Plant: Cherry Bomb
# --------------------------------------------------
#
# Plant: Split Pea
# --------------------------------------------------
#
# Plant: Chili Bean
# --------------------------------------------------
#
# Plant: Pea Pod
# --------------------------------------------------
#
# Plant: Lightning Reed
# --------------------------------------------------
#
# Plant: Melon-pult
# --------------------------------------------------
#
# Plant: Tall-nut
# --------------------------------------------------
#
# Plant: Winter Melon
# --------------------------------------------------
#
# Plant: Hot Potato
# --------------------------------------------------
#
# Plant: Pepper-pult
# --------------------------------------------------
#
# Plant: Chard Guard
# --------------------------------------------------
#
# Plant: Stunion
# --------------------------------------------------
#
# Plant: Rotobaga
# --------------------------------------------------
#
# Plant: Red Stinger
# --------------------------------------------------
#
# Plant: A.K.E.E.
# --------------------------------------------------
#
# Plant: Endurian
# --------------------------------------------------
#
# Plant: Stallia
# --------------------------------------------------
#
# Plant: Gold Leaf
# --------------------------------------------------
# Level upgrade table is not available :(
#
# Plant: Laser Bean
# --------------------------------------------------
#
# Plant: Blover
# --------------------------------------------------
#
# Plant: Citron
# --------------------------------------------------
#
# Plant: E.M.Peach
# --------------------------------------------------
#
# Plant: Infi-nut
# --------------------------------------------------
#
# Plant: Magnifying Grass
# --------------------------------------------------
#
# Plant: Tile Turnip
# --------------------------------------------------
# Level upgrade table is not available :(
#
# Plant: Sun-shroom
# --------------------------------------------------
#
# Plant: Puff-shroom
# --------------------------------------------------
#
# Plant: Fume-shroom
# --------------------------------------------------
#
# Plant: Sun Bean
# --------------------------------------------------
#
# Plant: Magnet-shroom
# --------------------------------------------------
#
# Plant: Phat Beet
# --------------------------------------------------
#
# Plant: Celery Stalker
# --------------------------------------------------
#
# Plant: Thyme Warp
# --------------------------------------------------
# Level upgrade table is not available :(
#
# Plant: Garlic
# --------------------------------------------------
#
# Plant: Spore-shroom
# --------------------------------------------------
#
# Plant: Intensive Carrot
# --------------------------------------------------
#
# Plant: Primal Peashooter
# --------------------------------------------------
#
# Plant: Primal Wall-nut
# --------------------------------------------------
#
# Plant: Perfume-shroom
# --------------------------------------------------
#
# Plant: Primal Sunflower
# --------------------------------------------------
#
# Plant: Primal Potato Mine
# --------------------------------------------------
#
# Plant: Lily Pad
# --------------------------------------------------
#
# Plant: Tangle Kelp
# --------------------------------------------------
#
# Plant: Bowling Bulb
# --------------------------------------------------
#
# Plant: Guacodile
# --------------------------------------------------
#
# Plant: Banana Launcher
# --------------------------------------------------
#
# Plant: Moonflower
# --------------------------------------------------
#
# Plant: Nightshade
# --------------------------------------------------
#
# Plant: Shadow-shroom
# --------------------------------------------------
#
# Plant: Dusk Lobber
# --------------------------------------------------
#
# Plant: Grimrose
# --------------------------------------------------
#
# Plant: Snow Pea
# --------------------------------------------------
#
# Plant: Power Lily
# --------------------------------------------------
#
# Plant: Imitater
# --------------------------------------------------
# Level upgrade table is not available :(
#
# Plant: Chomper
# --------------------------------------------------
#
# Plant: Toadstool
# --------------------------------------------------
#
# Plant: Strawburst
# --------------------------------------------------
#
# Plant: Cactus
# --------------------------------------------------
#
# Plant: Electric Blueberry
# --------------------------------------------------
#
# Plant: Jack O' Lantern
# --------------------------------------------------
#
# Plant: Grapeshot
# --------------------------------------------------
#
# Plant: Cold Snapdragon
# --------------------------------------------------
#
# Plant: Escape Root
# --------------------------------------------------
#
# Plant: Gold Bloom
# --------------------------------------------------
#
# Plant: Wasabi Whip
# --------------------------------------------------
#
# Plant: Kiwibeast
# --------------------------------------------------
#
# Plant: Apple Mortar
# --------------------------------------------------
#
# Plant: Witch Hazel
# --------------------------------------------------
# Error loading level upgrade page for plant: Witch Hazel
#
# Plant: Parsnip
# --------------------------------------------------
#
# Plant: Missile Toe
# --------------------------------------------------
#
# Plant: Caulipower
# --------------------------------------------------
#
# Plant: Electric Peashooter
# --------------------------------------------------
#
# Plant: Holly Barrier
# --------------------------------------------------
#
# Plant: Squash
# --------------------------------------------------
#
# Plant: Jalapeno
# --------------------------------------------------
#
# Plant: Hypno-shroom
# --------------------------------------------------
#
# Plant: Pea-nut
# --------------------------------------------------
#
# Plant: Homing Thistle
# --------------------------------------------------
#
# Plant: Ghost Pepper
# --------------------------------------------------
#
# Plant: Sweet Potato
# --------------------------------------------------
#
# Plant: Sap-fling
# --------------------------------------------------
#
# Plant: Hurrikale
# --------------------------------------------------
#
# Plant: Fire Peashooter
# --------------------------------------------------
#
# Plant: Lava Guava
# --------------------------------------------------
#
# Plant: Shrinking Violet
# --------------------------------------------------
#
# Plant: Electric Currant
# --------------------------------------------------
#
# Plant: Fila-mint
# --------------------------------------------------
#
# Plant: Pepper-mint
# --------------------------------------------------
#
# Plant: Winter-mint
# --------------------------------------------------
#
# Plant: Reinforce-mint
# --------------------------------------------------
#
# Plant: Bombard-mint
# --------------------------------------------------
#
# Plant: Ail-mint
# --------------------------------------------------
#
# Plant: Enchant-mint
# --------------------------------------------------
#
# Plant: Contain-mint
# --------------------------------------------------
#
# Plant: Enforce-mint
# --------------------------------------------------
#
# Plant: Arma-mint
# --------------------------------------------------
#
# Plant: Conceal-mint
# --------------------------------------------------
#
# Plant: Spear-mint
# --------------------------------------------------
#
# Plant: Appease-mint
# --------------------------------------------------
#
# Plant: Torchwood
# --------------------------------------------------
#
# Plant: Starfruit
# --------------------------------------------------
# Plant: Dandelion
# --------------------------------------------------
#
# Plant: Blooming Heart
# --------------------------------------------------
#
# Plant: Bombegranate
# --------------------------------------------------
#
# Plant: Explode-O-Nut
# --------------------------------------------------
#
# Plant: Aloe
# --------------------------------------------------
#
# Plant: Hot Date
# --------------------------------------------------
#
# Plant: Solar Tomato
# --------------------------------------------------
#
# Plant: Enlighten-mint
# --------------------------------------------------
#
# Plant: Shadow Peashooter
# --------------------------------------------------
#
# Plant: Goo Peashooter
# --------------------------------------------------
#
# Plant: Sling Pea
# --------------------------------------------------
#
# Plant: Snap Pea
# --------------------------------------------------
#
# Plant: Zoybean Pod
# --------------------------------------------------
#
# Plant: Electrici-tea
# --------------------------------------------------
#
# Plant: Dazey Chain
# --------------------------------------------------
#
# Plant: Blastberry Vine
# --------------------------------------------------
#
# Plant: Pokra
# --------------------------------------------------
#
# Plant: Imp Pear
# --------------------------------------------------
#
# Plant: Pyre Vine
# --------------------------------------------------
#
# Plant: Pumpkin
# --------------------------------------------------
#
# Plant: Ice Bloom
# --------------------------------------------------
#
# Plant: Dartichoke
# --------------------------------------------------
#
# Plant: Ultomato
# --------------------------------------------------
#
# Plant: Gumnut
# --------------------------------------------------
#
# Plant: Shine Vine
# --------------------------------------------------
#
# Plant: Tumbleweed
# --------------------------------------------------
#
# Plant: Olive Pit
# --------------------------------------------------
#
# Plant: Puffball
# --------------------------------------------------
#
# Plant: Explode-o-Vine
# --------------------------------------------------
#
# Plant: Murkadamia Nut
# --------------------------------------------------
#
# Plant: Turkey-pult
# --------------------------------------------------
#
# Plant: Headbutter Lettuce
# --------------------------------------------------
#
# Plant: Boingsetta
# --------------------------------------------------
#
# Plant: Stickybomb Rice
# --------------------------------------------------
#
# Plant: Hocus Crocus
# --------------------------------------------------
#
# Plant: Gloom Vine
# --------------------------------------------------
#
# Plant: Draftodil
# --------------------------------------------------
#
# Plant: Boom Balloon Flower
# --------------------------------------------------
#
# Plant: Pea Vine
# --------------------------------------------------
#
# Plant: Inferno
# --------------------------------------------------
#
# Plant: Solar Sage
# --------------------------------------------------
#
# Plant: Power Vine
# --------------------------------------------------
#
# Plant: Noctarine
# --------------------------------------------------
#
# Plant: Heath Seeker
# --------------------------------------------------
#
# Plant: Iceweed
# --------------------------------------------------
#
# Plant: Tiger Grass
# --------------------------------------------------
#
# Plant: Teleportato Mine
# --------------------------------------------------
#
# Plant: Blockoli
# --------------------------------------------------
#
# Plant: Buttercup
# --------------------------------------------------
#
# Plant: Bramble Bush
# --------------------------------------------------
#
# Plant: Marigold
# --------------------------------------------------
# Level upgrade table is not available :(

# %% [markdown]
# ## Future Works
#
# Currently known issues are listed below:
#
# - Tile Turnip: Plants **without family** does not have Level Upgrade table - this includes Tile Turnip, even though this plant is upgradable in Plants vs. Zombies 2 gameplay.
# - Witch Hazel: The **"Firing Rate"** needs to be treated differently due to the format of the values displayed (e.g. 17.25-18.25 seconds).
# - Escape Root: The subheaders below **"Damage"** are images of the following plants (from left to right): Potato Mine, Primal Potato Mine, Cherry Bomb, Jalapeno - manual treatment is required to replace column name "unnamed" caused on these column subheaders when loading HTML tables into `pandas` dataframe.
# - Others: Similar to Witch Hazel, the numeric values which are spelled-out (i.e., "One", "Two", "Three" instead of 1, 2, 3, etc.) in attributes of some plants such as "Duplications" and "Explosions" need to be treated and converted to numeric data types.
